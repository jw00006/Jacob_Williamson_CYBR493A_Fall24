# %%
"""
Web scrapping in Python
This is an example of scrapping a web page in Python using requests and lxml

"""
import requests
from lxml import html


def get_web_tree(link):
    """
    This method gets a web page from the specified url, and returns a tree of all elements in the page
    :param link: The webpage to access and process
    :return: The tree element created from the page
    """
    # Welcome message
    #print('Obtaining the page: ', str(link))
    # get the page
    page = requests.get(link)
    # get the elements from the page
    page_tree = html.fromstring(page.content)
    # return the tree of the web page
    return page_tree

# %%
# URL Tester
    url = "https://bugs.launchpad.net/ubuntu/+bugs?field.searchtext=&field.status%3Alist=EXPIRED&field.status%3Alist=CONFIRMED&field.status%3Alist=TRIAGED&field.status%3Alist=INPROGRESS&field.status%3Alist=FIXCOMMITTED&field.status%3Alist=FIXRELEASED&field.importance%3Alist=UNKNOWN&field.importance%3Alist=UNDECIDED&field.importance%3Alist=CRITICAL&field.importance%3Alist=HIGH&field.importance%3Alist=MEDIUM&field.importance%3Alist=LOW&field.importance%3Alist=WISHLIST&field.information_type%3Alist=PUBLIC&field.information_type%3Alist=PUBLICSECURITY&field.information_type%3Alist=PRIVATESECURITY&field.information_type%3Alist=USERDATA&assignee_option=any&field.assignee=&field.bug_reporter=&field.bug_commenter=&field.subscriber=&field.structural_subscriber=&field.component-empty-marker=1&field.tag=&field.tags_combinator=ANY&field.status_upstream-empty-marker=1&field.has_cve.used=&field.omit_dupes.used=&field.omit_dupes=on&field.affects_me.used=&field.has_no_package.used=&field.has_patch.used=&field.has_branches.used=&field.has_branches=on&field.has_no_branches.used=&field.has_no_branches=on&field.has_blueprints.used=&field.has_blueprints=on&field.has_no_blueprints.used=&field.has_no_blueprints=on&search=Search&orderby=-importance&"
    print(url)
    pageCount = 0
    bugsPerPage = 75
    maxPages = 3
    
    
    while(pageCount < maxPages):
        newStart = pageCount * bugsPerPage
        newUrl = url + str("memo=") + str(newStart) + str("&start=") + str(newStart)
        print(newUrl)
        pageCount += 1

# %%
def main():
    #url without "memo=" and "&start="
    url = "https://bugs.launchpad.net/ubuntu/+bugs?field.searchtext=&field.status%3Alist=EXPIRED&field.status%3Alist=CONFIRMED&field.status%3Alist=TRIAGED&field.status%3Alist=INPROGRESS&field.status%3Alist=FIXCOMMITTED&field.status%3Alist=FIXRELEASED&field.importance%3Alist=UNKNOWN&field.importance%3Alist=UNDECIDED&field.importance%3Alist=CRITICAL&field.importance%3Alist=HIGH&field.importance%3Alist=MEDIUM&field.importance%3Alist=LOW&field.importance%3Alist=WISHLIST&field.information_type%3Alist=PUBLIC&field.information_type%3Alist=PUBLICSECURITY&field.information_type%3Alist=PRIVATESECURITY&field.information_type%3Alist=USERDATA&assignee_option=any&field.assignee=&field.bug_reporter=&field.bug_commenter=&field.subscriber=&field.structural_subscriber=&field.component-empty-marker=1&field.tag=&field.tags_combinator=ANY&field.status_upstream-empty-marker=1&field.has_cve.used=&field.omit_dupes.used=&field.omit_dupes=on&field.affects_me.used=&field.has_no_package.used=&field.has_patch.used=&field.has_branches.used=&field.has_branches=on&field.has_no_branches.used=&field.has_no_branches=on&field.has_blueprints.used=&field.has_blueprints=on&field.has_no_blueprints.used=&field.has_no_blueprints=on&search=Search&orderby=-importance&"
    
    pageCount = 0
    bugsPerPage = 75
    maxPages = 3 #so that program doesn't scrap entirety of bugzilla
    
    while(pageCount < maxPages):
        newStart = pageCount * bugsPerPage
        newUrl = url + str("memo=") + str(newStart) + str("&start=") + str(newStart)
        
        main_tree = get_web_tree(newUrl)
        bugs = main_tree.xpath('//*[@class="buglisting-row"]')

        for bug in bugs:
            bugImportance = bug.xpath('.//div["buglisting-col1"]//text()')
            number = bugImportance[9].strip()
            severity = bugImportance[1].strip()
            status = bugImportance[3].strip()
            heat = bugImportance[18].strip()
            summary = bugImportance[11].strip()
            
            print(f"{number}, {severity}, {status}, {heat}, {summary}")
        print("END PAGE")
        pageCount += 1
        
if __name__ == "__main__":
    main()
# Out:
# #39208, Unknown, Fix Released, 14, kded crash frequently
# #66752, Unknown, Fix Released, 8, Bitpim uses 100% CPUs and fills all memory
# #93885, Unknown, Fix Released, 30, It's completely broken: missing org/mozilla/javascript/tools/shell/Main
# #105713, Unknown, Fix Released, 8, kgpg can't delete key pairs
# #139649, Unknown, Fix Released, 34, Troubles with mtp in mtp-detect and Rhythmbox with a cowon D2
# #160830, Unknown, Fix Released, 4, Please sync Postfix from Debian Unstable (Main)
# #86798, Unknown, Fix Released, 160, r8169 driver does not detect link
# #53216, Unknown, Fix Released, 336, BUG() report in getnstimeofday: soft lockup
# #177628, Unknown, Fix Released, 2, Wrong Exec= in desktop files in koffice 2.0 package
# #144030, Unknown, Fix Released, 26, Gutsy beta hang soon after boot
# #1393202, Unknown, Fix Released, 6, in rope training game the target don't disappear when one kicks them
# #1516025, Unknown, Confirmed, 260, Realtek ALC3661 Alienware14 / Soundoutput / Jack
# #1779238, Unknown, Fix Released, 20, Mouting a disk or iso image asks for sudo password
# #1956603, Unknown, Fix Released, 12, > Internal error:   Could not resolve keysym ...
# #1, Critical, Fix Released, 10702, Microsoft has a majority market share
# #462, Critical, Fix Released, 16, Can't install kdelibs-data, duplicate file with knetworkconf
# #514, Critical, Fix Released, 6, Remove amarok-artsd
# #768, Critical, Fix Released, 4, 2.0.1-7ubuntu2 fubar, rebuilt 2.0.4-1 from Debian Testing fine
# #1051, Critical, Fix Released, 4, razor-agents 2.71
# #2460, Critical, Fix Released, 12, vpnc_0.3.3 doesn't include vpnc-connect script.
# #2565, Critical, Fix Released, 32, [Breezy Colony 5]scim refuses to start, scim-setup segfaults
# #7135, Critical, Fix Released, 10, package installation fails without giving an obvious reason [disk is full]
# #7201, Critical, Fix Released, 4, postfix ubuntu3 postinst broken
# #7265, Critical, Fix Released, 6, portmap must not listen on external interfaces by default
# #7412, Critical, Fix Released, 4, partman doesn't allow to specify partition size in manual mode
# #7698, Critical, Fix Released, 6, evolution-exchange: depends on libsoup2.2-3 which isn't available
# #7702, Critical, Fix Released, 16, Admin applications use gksu, should use gksudo
# #7727, Critical, Fix Released, 6, evolution-webcal uninstallable
# #7773, Critical, Fix Released, 16, gdm broken with the missing "human" theme
# #7781, Critical, Fix Released, 12, ubuntu artwork human theme icons are HUGE
# #7809, Critical, Fix Released, 10, gdm doesn't start after base-config completes a fresh install
# #7819, Critical, Fix Released, 4, gksudo segfaults at the end
# #7868, Critical, Fix Released, 18, Epiphany is not installed, but still seems to be GNOME's default browser
# #7900, Critical, Fix Released, 4, gnome-cups-manager prints administrator password on stdout
# #7921, Critical, Fix Released, 4, DHCP isn't started when using wartylive
# #7931, Critical, Fix Released, 6, xresprobe resolution output has been modified breaking X autodetection.
# #7934, Critical, Fix Released, 6, FBDEV detection fails
# #7945, Critical, Fix Released, 26, no middle + right mouse button on powerbooks
# #7947, Critical, Fix Released, 8, firefox menu item to be renamed
# #7959, Critical, Fix Released, 4, Evolution menu item changes
# #7966, Critical, Fix Released, 6, ubuntu-artwork icon reversions
# #7967, Critical, Fix Released, 24, syntax error in samba-common.configure
# #7968, Critical, Fix Released, 6, base-installer needs to be taught about linux-restricted-modules
# #7984, Critical, Fix Released, 4, desktop defaults changes for mark
# #7985, Critical, Fix Released, 6, Integrate final artwork
# #7988, Critical, Fix Released, 4, Component selector is missing most packages
# #8053, Critical, Fix Released, 10, gnome-themes is uninstallable
# #8056, Critical, Fix Released, 6, xchat crashes if locale is UTF-8 but real name in /etc/passwd is in ISO-8859-1
# #8178, Critical, Fix Released, 8, ubuntu-artwork fails to install if grub is unconfigured
# #8301, Critical, Fix Released, 26, Bootloader does not start the kernel
# #8315, Critical, Fix Released, 6, /dev/tty broken on console
# #8317, Critical, Fix Released, 4, Wrong URL in Computer > About Ubuntu...
# #8361, Critical, Fix Released, 4, ubuntu20 locks up powerbooks
# #8362, Critical, Fix Released, 8, therm_adt746x not loaded on iBook G4
# #8369, Critical, Fix Released, 4, System freezes when starting X on an Asus laptop with ATI Mobility Radeon M7
# #8385, Critical, Fix Released, 8, ubuntu-sounds conflicts with gnome-audio
# #8389, Critical, Fix Released, 6, Kernel crash in usb.rc on initial reboot
# #8521, Critical, Fix Released, 6, Fails to build from source on amd64, powerpc
# #8591, Critical, Fix Released, 6, gzip hangs in futex(..., FUTEX_WAIT) indefinetely
# #8716, Critical, Fix Released, 20, Important Security Update for Firefox Available
# #8723, Critical, Fix Released, 8, hal doesn't start on live CD
# #8873, Critical, Fix Released, 12, File overlap between flavours
# #8943, Critical, Fix Released, 4, CAN-2004-0923: Device URIs containning username & password end up in error_log
# #9043, Critical, Fix Released, 6, umask change broke CD-ROM access in some cases
# #9063, Critical, Fix Released, 12, fan and thermal modules loaded in wrong order
# #9066, Critical, Fix Released, 4, CAN-2004-0803, CAN-2004-0890: Multiple vulnerabilities in libtiff
# #9082, Critical, Fix Released, 8, gnome-device-manager (hal) crashes as soon as it is launched in LiveCD
# #9324, Critical, Fix Released, 6, live CD: localisation is broken
# #9707, Critical, Fix Released, 4, Debian merge reverted localhost-only listening patch
# #9744, Critical, Fix Released, 4, LiveCD build process violates policy
# #9781, Critical, Fix Released, 4, jfsutils out of date, unresolvable catch 222 after crash using kernel 2.6
# #10017, Critical, Fix Released, 6, Potential Remote Denial of Service Vulnerability in Samba 3.0.x <= 3.0.7
# #10255, Critical, Fix Released, 8, error during startup: accessKey="&allowPopups.accessKey;"
# #10396, Critical, Fix Released, 8, Kernel 2.6.9 & below smbfs vulnerability
# #10638, Critical, Fix Released, 8, Does not lock memory
# END PAGE
# #10714, Critical, Fix Released, 4, Live cd doesn't boot
# #10742, Critical, Fix Released, 6, Fails to build from source
# #11037, Critical, Fix Released, 20, cupsys upgrade error (cupsys won't stop)
# #11147, Critical, Fix Released, 6, gnome-menus conflicts with kdelibs-data in /etc/xdg/menus/applications.menu
# #11193, Critical, Fix Released, 10, [warty] Firefox Window Injection Vulnerability
# #11283, Critical, Fix Released, 58, gnome-panel / nautilus hang due to gnome-vfs-daemon
# #11286, Critical, Fix Released, 20, 6.8.1-1ubuntu7 is broken
# #11438, Critical, Fix Released, 8, can't configure python2.4-minimal without python2.4 installed
# #11550, Critical, Fix Released, 14, Python 2.4 breaks Bittorrent
# #11574, Critical, Fix Released, 18, Network Places menu has trouble opening sftp in nautilus
# #11623, Critical, Fix Released, 4, Ubuntu-specific changes lost in merge
# #11829, Critical, Fix Released, 6, Several modules unloadable in 2.6.10-4
# #11855, Critical, Fix Released, 24, gtksourceview-sharp should no provide nemerle.lang
# #11885, Critical, Fix Released, 4, reportbug has python2.3 hardcoded
# #11897, Critical, Fix Released, 8, Gnome-panel seems to have a mismatched dependancy (AMD64)
# #11904, Critical, Fix Released, 8, vgchange segfaults with 2.6.10-2
# #11974, Critical, Fix Released, 12, vbestate save causes hang on some systems
# #12114, Critical, Fix Released, 4, install fails on AMD64
# #12209, Critical, Fix Released, 10, Metacity titlebar odity
# #12239, Critical, Fix Released, 4, Ubuntu changes lost in merge?
# #12254, Critical, Fix Released, 20, Evolution-data-server crashes with floating point exception
# #12347, Critical, Fix Released, 6, HOARY: gnopernicus: fails to start - lib problems
# #12386, Critical, Fix Released, 22, grub installation hangs at 33%
# #12459, Critical, Fix Released, 10, GRUB segfaults on amd64
# #12467, Critical, Fix Released, 10, Gnome Users and Groups: Changing a user's UID breaks the account
# #12560, Critical, Fix Released, 8, after upgrading to hoary on ibook G3, screen is in quarters
# #12599, Critical, Fix Released, 20, Large number of udev processes spawned
# #12683, Critical, Fix Released, 20, trying to overwrite `/usr/share/icons/hicolor/48x48/apps/gnome-run.png', which is also in package gnome-panel-data
# #12721, Critical, Fix Released, 8, python2.4-minimal must not be essential
# #12753, Critical, Fix Released, 6, /usr/bin/twistd fails to run with "ImportError: No module named profile"
# #12939, Critical, Fix Released, 22, polypaudio crasher on powerpc
# #12940, Critical, Fix Released, 6, Kernel Panic with new kernel-2.6.10-3 when logging in
# #12961, Critical, Fix Released, 4, NIC detection error in installer - ubuntu-sparc
# #12972, Critical, Fix Released, 10, Kernel update missing corresponding linux-restricted-modules update
# #12977, Critical, Fix Released, 6, Default kernel parameters missing on live CD
# #13036, Critical, Fix Released, 8, Hoary Install not recognized the SCSI-Harddisk to install onto
# #13404, Critical, Fix Released, 12, Language packs broken, due to "dependency cycle"
# #13458, Critical, Fix Released, 4, emacs21: FTBFS: timestamp skew issues.
# #13499, Critical, Fix Released, 14, Improper boundary checking -> SIGSEGV
# #13522, Critical, Fix Released, 8, i810 from HEAD is unusable
# #13645, Critical, Fix Released, 8, Kmail segfaults
# #13753, Critical, Fix Released, 14, language-pack upgrades are fragile
# #13830, Critical, Fix Released, 24, ABI compatibility changed in 2.6.10-4-26
# #13888, Critical, Fix Released, 4, db3 sets LD_ASSUME_KERNEL on amd64
# #14069, Critical, Fix Released, 6, Installer asks for time zone after copy of packages to hard drive
# #14160, Critical, Fix Released, 8, fontconfig error update
# #14176, Critical, Fix Released, 36, libc does not do per-domain result caching
# #14186, Critical, Fix Released, 4, FTBFS: can't find -lgvgd
# #14190, Critical, Fix Released, 4, Fails to insatll - debconf errors
# #14223, Critical, Fix Released, 8, FTBFS: g++ errors
# #14224, Critical, Fix Released, 4, FTBFS: LinuxThreads not found
# #14226, Critical, Fix Released, 4, FTBFS: Undefined reference.
# #14227, Critical, Fix Released, 8, FTBFS: patch fails.
# #14229, Critical, Fix Released, 8, FTBFS: conflicting build-deps
# #14235, Critical, Fix Released, 14, Java VM locking on highly multithreaded Java apps
# #14252, Critical, Fix Released, 6, FTBFS: can't find libktnef.la
# #14271, Critical, Fix Released, 8, gnome-vfs-daemon segfault
# #14274, Critical, Fix Released, 8, FTBFS: segv in ld
# #14277, Critical, Fix Released, 12, Hang while loading snd-nm256 module
# #14283, Critical, Fix Released, 6, klogd stops logging after some time
# #14355, Critical, Fix Released, 24, libapache2-mod-php4 breaks Squirrelmail and Gallery
# #14436, Critical, Fix Released, 4, FTBFS: missing headers
# #14536, Critical, Fix Released, 8, can't log in after installation because of wrong keymap
# #14537, Critical, Fix Released, 6, ubuntu install leaves me unable to boot my fedora core 3 installation
# #14815, Critical, Fix Released, 4, FTBFS: broken build-depends
# #14816, Critical, Fix Released, 4, FTBFS: autobmake versionitis
# #14832, Critical, Fix Released, 4, Warty->Hoary upgrade failure on amd64 due to file conflict
# #14889, Critical, Fix Released, 4, FTBFS: bad patch
# #14909, Critical, Fix Released, 6, Processor bug causes p4-clockmod to shut Pentium 4 laptop down
# #15001, Critical, Fix Released, 74, Administrator mode not working
# #15011, Critical, Fix Released, 6, should conflict with xfree86-driver-synaptics?
# #16038, Critical, Fix Released, 10, Installer fails to write grub to mbr?
# #16231, Critical, Fix Released, 30, Code execution through javascript: favicons
# #16232, Critical, Fix Released, 8, Arbitrary code execution from Firefox sidebar panel II
# #16233, Critical, Fix Released, 8, Privilege escalation via DOM property overrides
# END PAGE
# #16306, Critical, Fix Released, 22, Incorrect permissions for printer devices
# #16364, Critical, Fix Released, 40, boottime.kmap.gz is not loaded at boot : problem with install-keymap and/or loadkeys
# #16933, Critical, Fix Released, 4, SATA drives aren't created with Breezy
# #17030, Critical, Fix Released, 8, libdbus-qt-1-1 needed in main (breezy)
# #17233, Critical, Fix Released, 156, Many keys suddenly bound to incorrect actions
# #17237, Critical, Fix Released, 8, gcc-4.0 miscompiles libpng2/libpng3 on powerpc with -O3
# #17303, Critical, Fix Released, 16, Upgrade from warty to hoary causes missing getty, hwclock, dmesg (more?) binaries
# #17334, Critical, Fix Released, 6, bash hangs after every command when running on Linux < 2.6.10
# #17346, Critical, Fix Released, 26, Missing /usr/lib/X11/fonts/misc symlink
# #17353, Critical, Fix Released, 16, Xorg fails to start due to broken symlink
# #17402, Critical, Fix Released, 20, [Breezy] Synaptic segfaults at startup
# #17472, Critical, Fix Released, 6, iBook freeze after hibernate, reason usbcore? kernel 2.6.10-5-powerpc
# #17523, Critical, Fix Released, 30, VMware BusLogic scsi device not detected
# #17535, Critical, Fix Released, 26, Cannot compile after upgrading binutils to 2.15-5ubuntu2.1 from hoary-security/main
# #17622, Critical, Fix Released, 4, calendar segfault
# #18035, Critical, Fix Released, 8, make-kpkg can't find gcc (fix install scripts for it?)
# #18289, Critical, Fix Released, 8, crash in tiff loader
# #18444, Critical, Fix Released, 8, latest (libx11-6 1:6.2.1+cvs.20050615-3) version lacks XauGetBestAuthByAddr symbol
# #18690, Critical, Fix Released, 6, php4-pear security update has fatal typo in /usr/share/php/XML/RPC.php
# #18868, Critical, Fix Released, 8, Doesn't install properly
# #19138, Critical, Fix Released, 10, Firefox does not download  files after the last security update
# #19171, Critical, Fix Released, 162, where is my /dev/input/mice on breezy?
# #19208, Critical, Fix Released, 8, Missing symlink from /usr/lib/X11/locale/common to /usr/share/X11/locale/lib/common
# #19310, Critical, Fix Released, 8, major data loss in IMAP code
# #19566, Critical, Fix Released, 8, firefox clear search history function only stays cleared on clean quit not a crash
# #19609, Critical, Fix Released, 20, initramfs: doesn't work with lilo as bootloader
# #19631, Critical, Fix Released, 22, Cannot boot with root partition as logical volume with "-" in the name
# #19641, Critical, Fix Released, 24, eth0 not mapped by hotplug
# #19774, Critical, Fix Released, 12, 0 size xorg.conf after 20050816 breezy install
# #19834, Critical, Fix Released, 60, gworkspace.app: Loader error when launching GWorkspace
# #19966, Critical, Fix Released, 36, [locale] non-UTF8 fallen out of NLS data files (hoary regr.)
# #20177, Critical, Fix Released, 8, Kernel panic at boot, failed found hd device. (initrd havent atiixp module)
# #20291, Critical, Fix Released, 12, Exchange plugin doesn't work with breezy
# #20297, Critical, Fix Released, 18, Hibernate does not work with usplash
# #20465, Critical, Fix Released, 20, udev does not initialize device nodes at boot time
# #20571, Critical, Fix Released, 6, openoffice.org2 is uninstallable on amd64
# #20586, Critical, Fix Released, 6, Depends on toshset which doesn't work on ACPI-enabled kernels.
# #20738, Critical, Fix Released, 6, /etc/cron.daily/apt should check ctime as well as mtime
# #20852, Critical, Fix Released, 6, PyQT doesn't work in breezy - underined symbol error _ZT111QMotifStyle
# #21080, Critical, Fix Released, 10, Live CD fails to switch back to vt1, obscuring shutdown messages
# #21408, Critical, Fix Released, 8, Powerbook special keys not working on newer powerbooks
# #21755, Critical, Fix Released, 6, [lib32gcc1] wrong version or wrong shlibs file.
# #21915, Critical, Fix Released, 22, esound causes desktop session to hang
# #21922, Critical, Fix Released, 30, /init: 64: Syntax error: 0x
# #21933, Critical, Fix Released, 10, 5.10 Preview's X.org shows vertical streaks, complete screen flickering, and some "ghost" images on an AGP S3 Savage 4 video card
# #21983, Critical, Fix Released, 8, x11proto-gl file overwrite errors with hoary xlibmesa-gl-dev
# #21988, Critical, Fix Released, 8, Fails to resume with initramfs-tools_0.26
# #22385, Critical, Fix Released, 16, capability module is not loaded, breaking apps
# #22503, Critical, Fix Released, 6, Marvell 88E8053 isn't recognized
# #22810, Critical, Fix Released, 6, grepmap 1.0.0-1 segfaults
# #22857, Critical, Fix Released, 42, default homepage does not exist anymore
# #22913, Critical, Fix Released, 6, mounting of nfs filesystems on bootup unreliable
# #23142, Critical, Fix Released, 12, Missing "then" keyword in sleep.sh script
# #23166, Critical, Fix Released, 32, "About Ubuntu" fails
# #23301, Critical, Fix Released, 10, CD images are oversized
# #24593, Critical, Fix Released, 12, [r3xx] r300 dri is badly broken
# #26338, Critical, Fix Released, 390, Changing users randomly affects other users and group memberships
# #26851, Critical, Fix Released, 46, dapper: firefox 1.5 breaks with many/all locale packs
# #26979, Critical, Fix Released, 4, /etc/cups/interfaces and /var/run/cups/printcap have the wrong owners
# #27350, Critical, Fix Released, 10, serviceconfig crashes with error
# #27394, Critical, Fix Released, 42, Latest version doesn't provide certificate authorities
# #27531, Critical, Fix Released, 14, breaks breezy -> dapper upgrades
# #27539, Critical, Fix Released, 28, issue in booting live dvd
# #27976, Critical, Fix Released, 6, Yaboot skip the prompt in installer
# #28067, Critical, Fix Released, 40, [PATCH] initscripts: checkroot.sh ignores fsck result
# #28140, Critical, Fix Released, 10, [live cd] User 'ubuntu' cannot log in
# #28290, Critical, Fix Released, 4, rc crashes if booting w/o initrd
# #28841, Critical, Fix Released, 10, Gnome volume-manager quits just before Desktop shows
# #28911, Critical, Fix Released, 10, x11-common is uninstallable
# #29564, Critical, Fix Released, 8, xorg.conf is left empty by installer
# #30940, Critical, Fix Released, 6, buffer overflow vulnerability in code generated by flex
# #31457, Critical, Fix Released, 28, Latest unzip update breaks programs dependent on unzip output
# #31716, Critical, Fix Released, 4, PATH only contains /bin:/usr/bin on new installs
# #31910, Critical, Fix Released, 26, Dejavu Sans crashes applications for specific characters
# #32199, Critical, Fix Released, 6, Speech-dispatcher does nt start properly on dapper, due to /var/run being mounted tmpfs.
# END PAGE
